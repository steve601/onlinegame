# %% [markdown]
# ## Predict Online Gaming Behavior Dataset
# ###
# Explore Player Engagement Patterns in Online Gaming

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/odhia/OneDrive/Desktop/mlopsProjects/notebook/data/online_gaming_behavior_dataset.csv')
df.head()
# Out:
#    PlayerID  Age  Gender Location GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43    Male    Other  Strategy      16.271119                0
# 1      9001   29  Female      USA  Strategy       5.525961                0
# 2      9002   22  Female      USA    Sports       8.223755                0
# 3      9003   35    Male      USA    Action       5.265351                1
# 4      9004   33    Male   Europe    Action      15.531945                0
#
#   GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0         Medium                6                        108           79
# 1         Medium                5                        144           11
# 2           Easy               16                        142           35
# 3           Easy                9                         85           57
# 4         Medium                2                        131           95
#
#    AchievementsUnlocked EngagementLevel
# ...

# %%
df.drop('PlayerID',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40034 entries, 0 to 40033
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        40034 non-null  int64
#  1   Gender                     40034 non-null  object
#  2   Location                   40034 non-null  object
#  3   GameGenre                  40034 non-null  object
#  4   PlayTimeHours              40034 non-null  float64
#  5   InGamePurchases            40034 non-null  int64
#  6   GameDifficulty             40034 non-null  object
#  7   SessionsPerWeek            40034 non-null  int64
#  8   AvgSessionDurationMinutes  40034 non-null  int64
#  9   PlayerLevel                40034 non-null  int64
#  10  AchievementsUnlocked       40034 non-null  int64
#  11  EngagementLevel            40034 non-null  object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 3.7+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Age: Age of the player.
# ### Gender: Gender of the player.-
# ### Location: Geographic location of the player- .
# ### GameGenre: Genre of the game the player is engaged i- n.
# ### PlayTimeHours: Average hours spent playing per sessi- on.
# ### InGamePurchases: Indicates whether the player makes in-game purchases (0 = No, 1 = Y- es).
# ### GameDifficulty: Difficulty level of the - game.
# ### SessionsPerWeek: Number of gaming sessions per-  week.
# ### AvgSessionDurationMinutes: Average duration of each gaming session in m- inutes.
# ### PlayerLevel: Current level of the player in t- he game.
# ### AchievementsUnlocked: Number of achievements unlocked by tm## ', 'Low').
# ## Targe- t Variable:
# ### EngagementLevel: Indicates the level of player engagement categorized as 'High', 'Medium', or 'Low'.

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['age', 'gender', 'location', 'gamegenre', 'playtimehours',
#        'ingamepurchases', 'gamedifficulty', 'sessionsperweek',
#        'avgsessiondurationminutes', 'playerlevel', 'achievementsunlocked',
#        'engagementlevel'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age  playtimehours  ingamepurchases  sessionsperweek  \
# count  40034.000000   40034.000000     40034.000000     40034.000000
# mean      31.992531      12.024365         0.200854         9.471774
# std       10.043227       6.914638         0.400644         5.763667
# min       15.000000       0.000115         0.000000         0.000000
# 25%       23.000000       6.067501         0.000000         4.000000
# 50%       32.000000      12.008002         0.000000         9.000000
# 75%       41.000000      17.963831         0.000000        14.000000
# max       49.000000      23.999592         1.000000        19.000000
#
#        avgsessiondurationminutes   playerlevel  achievementsunlocked
# count               40034.000000  40034.000000          40034.000000
# mean                   94.792252     49.655568             24.526477
# std                    49.011375     28.588379             14.430726
# min                    10.000000      1.000000              0.000000
# ...

# %% [markdown]
# ### Cat. columns

# %% [markdown]
# ### gender

# %%
df.gender.value_counts()
# Out:
# gender
# Male      23959
# Female    16075
# Name: count, dtype: int64

# %%
plt.figure(figsize=(13,5))
x = df.gender.value_counts()
mylabels = ["Male",'Female']
myexplode = [0.2, 0]

plt.pie(x, labels = mylabels, explode = myexplode, shadow = True)
plt.legend()
plt.title('Gender distribution')
plt.show()

# %% [markdown]
# ### location

# %%
df.location.value_counts()
# Out:
# location
# USA       16000
# Europe    12004
# Asia       8095
# Other      3935
# Name: count, dtype: int64

# %%
sns.countplot(x=df.location)
# Out:
# <Axes: xlabel='location', ylabel='count'>

# %% [markdown]
# ### gamegenre

# %%
df.gamegenre.value_counts()
# Out:
# gamegenre
# Sports        8048
# Action        8039
# Strategy      8012
# Simulation    7983
# RPG           7952
# Name: count, dtype: int64

# %%
sns.countplot(x=df.gamegenre)
# Out:
# <Axes: xlabel='gamegenre', ylabel='count'>

# %% [markdown]
# ### gamedifficulty

# %%
df.gamedifficulty.value_counts()
# Out:
# gamedifficulty
# Easy      20015
# Medium    12011
# Hard       8008
# Name: count, dtype: int64

# %%
sns.countplot(x=df.gamedifficulty)
# Out:
# <Axes: xlabel='gamedifficulty', ylabel='count'>

# %% [markdown]
# ### engagementlevel

# %%
df.engagementlevel.value_counts()
# Out:
# engagementlevel
# Medium    19374
# High      10336
# Low       10324
# Name: count, dtype: int64

# %%
sns.countplot(x=df.engagementlevel)
# Out:
# <Axes: xlabel='engagementlevel', ylabel='count'>

# %% [markdown]
# ### Num. columns

# %% [markdown]
# ### age

# %%
sns.histplot(x=df.age,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x=df.age)
# Out:
# <Axes: xlabel='age'>

# %%
df.columns
# Out:
# Index(['age', 'gender', 'location', 'gamegenre', 'playtimehours',
#        'ingamepurchases', 'gamedifficulty', 'sessionsperweek',
#        'avgsessiondurationminutes', 'playerlevel', 'achievementsunlocked',
#        'engagementlevel'],
#       dtype='object')

# %%
sns.histplot(x=df.playtimehours)
# Out:
# <Axes: xlabel='playtimehours', ylabel='Count'>

# %%
sns.boxplot(x=df.playtimehours)
# Out:
# <Axes: xlabel='playtimehours'>

# %% [markdown]
# ### ingamepurchases

# %%
sns.countplot(x=df.ingamepurchases)
# Out:
# <Axes: xlabel='ingamepurchases', ylabel='count'>

# %% [markdown]
# ### sessionsperweek

# %%
sns.histplot(x=df.sessionsperweek)
# Out:
# <Axes: xlabel='sessionsperweek', ylabel='Count'>

# %% [markdown]
# ### avgsessiondurationminutes

# %%
sns.histplot(x=df.avgsessiondurationminutes)
# Out:
# <Axes: xlabel='avgsessiondurationminutes', ylabel='Count'>

# %% [markdown]
# ### playerlevel

# %%
sns.kdeplot(x=df.playerlevel)
# Out:
# <Axes: xlabel='playerlevel', ylabel='Density'>

# %% [markdown]
# ### achievementsunlocked

# %%
sns.kdeplot(x=df.achievementsunlocked)
# Out:
# <Axes: xlabel='achievementsunlocked', ylabel='Density'>

# %%
df['playtimehours'] = df['playtimehours'].astype('int64')
df.head()
# Out:
#    age  gender location gamegenre  playtimehours  ingamepurchases  \
# 0   43    Male    Other  Strategy             16                0
# 1   29  Female      USA  Strategy              5                0
# 2   22  Female      USA    Sports              8                0
# 3   35    Male      USA    Action              5                1
# 4   33    Male   Europe    Action             15                0
#
#   gamedifficulty  sessionsperweek  avgsessiondurationminutes  playerlevel  \
# 0         Medium                6                        108           79
# 1         Medium                5                        144           11
# 2           Easy               16                        142           35
# 3           Easy                9                         85           57
# 4         Medium                2                        131           95
#
#    achievementsunlocked engagementlevel
# 0                    25          Medium
# 1                    10          Medium
# ...

# %%
sns.pairplot(df)

# %%
df.gender = df.gender.map({
    'Male':0,
    'Female':1
})
df.gamedifficulty = df.gamedifficulty.map({
    'Easy':0,
    'Medium':1,
    'Hard':2
})
df.engagementlevel = df.engagementlevel.map({
    'Low':0,
    'Medium':1,
    'High':2
})

# %%
num_cols = ['age','playtimehours','sessionsperweek','avgsessiondurationminutes','playerlevel','achievementsunlocked','engagementlevel']
df_num = df[num_cols]
cor = df_num.corr()
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
df.drop(['age','playtimehours'],axis=1,inplace=True)
df.head()
# Out:
#    gender location gamegenre  ingamepurchases  gamedifficulty  \
# 0       0    Other  Strategy                0               1
# 1       1      USA  Strategy                0               1
# 2       1      USA    Sports                0               0
# 3       0      USA    Action                1               0
# 4       0   Europe    Action                0               1
#
#    sessionsperweek  avgsessiondurationminutes  playerlevel  \
# 0                6                        108           79
# 1                5                        144           11
# 2               16                        142           35
# 3                9                         85           57
# 4                2                        131           95
#
#    achievementsunlocked  engagementlevel
# 0                    25                1
# 1                    10                1
# 2                    41                2
# 3                    47                1
# ...

# %%
df.to_csv('C:/Users/odhia/OneDrive/Desktop/mlopsProjects/notebook/data/precessed_data.csv',index=False)

# %%
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
enc_cols = ['location','gamegenre']
sc_cols = ['gender','ingamepurchases','gamedifficulty','sessionsperweek','avgsessiondurationminutes','playerlevel','achievementsunlocked']
encoder = OneHotEncoder()
scaler = StandardScaler(with_mean=False)

enc_pipe = Pipeline(steps=[
    ('encoder',OneHotEncoder()),
    ('scaler',StandardScaler(with_mean=False))
])
sc_pipe = Pipeline(steps=[
    ('scaler',StandardScaler(with_mean=False))
])

preprocessor = ColumnTransformer([
    ('enc_pipe',enc_pipe,enc_cols),
    ('sc_pipe',sc_pipe,sc_cols)
])

# %%
X = df.drop('engagementlevel',axis=1)
y = df['engagementlevel']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
models = {
    'Logistic Regression':LogisticRegression(),
    'SVC':SVC(),
    'KNeighbours':KNeighborsClassifier(),
    'Cat Boost':CatBoostClassifier(logging_level='Silent'),
    'XGB':XGBClassifier(),
    'Decision Tree':DecisionTreeClassifier(),
    'Random Forest':RandomForestClassifier(),  
}

# %%
report = {}
print("Models' Report")
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)
    prediction = model.predict(X_test)
    score = accuracy_score(y_test,prediction)
    report[list(models.keys())[i]] = score
best_score = max(sorted(list(report.values())))
for k,v in report.items():
    if v == best_score:
        best_model_name = k
        break
print(report)
print(f"{best_model_name} is the best model with accuracy of {best_score}")
# Out:
# Models' Report
# {'Logistic Regression': 0.8190628434409032, 'SVC': 0.8868018783095214, 'KNeighbours': 0.7600159856129484, 'Cat Boost': 0.9152762513737636, 'XGB': 0.91187930862224, 'Decision Tree': 0.831651513637726, 'Random Forest': 0.9044859626336297}
# Cat Boost is the best model with accuracy of 0.9152762513737636
